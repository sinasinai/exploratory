# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine, types
from dotenv import load_dotenv
import numpy as np
import math 

load_dotenv()

import os

# %%
def generate_schema(df):

    schema = {}

    for c in df.columns:

        if df[c].dtype == np.dtype("int64"):
            schema[c] = types.BIGINT()
        elif df[c].dtype == np.dtype("float64"):
            schema[c] = types.Float(asdecimal=True)
        elif df[c].dtype == np.dtype("datetime64[ns]"):
            schema[c] = types.DateTime(timezone=False)
        elif df[c].dtype == np.dtype("bool"):
            schema[c] = types.BOOLEAN()
        else:
            schema[c] = types.VARCHAR(length=65535)

    return schema

# %% [markdown]
# <b>[Parcel data](https://www.opendataphilly.org/dataset/property-parcels)</b> and <b>[property assessment data](https://www.opendataphilly.org/dataset/opa-property-assessments)</b> links on Philly's Open Data site. <b>[Business (rental) license data](https://www.opendataphilly.org/dataset/licenses-and-inspections-business-licenses/resource/bc00c2db-2d8f-421f-94f4-6e24531d661a)</b> can be found on the site too

# %%
with open('opa_properties_public.geojson','r') as f:
    properties = json.load(f)

# %%
properties_df = pd.json_normalize(properties['features'])
properties_df.head()
# Out:
#       type geometry.type     geometry.coordinates properties.assessment_date  \
# 0  Feature         Point  [-75.146866, 39.931278]                       None
# 1  Feature         Point  [-75.146921, 39.931286]                       None
# 2  Feature         Point  [-75.146971, 39.931292]                       None
# 3  Feature         Point   [-75.147034, 39.93123]                       None
# 4  Feature         Point  [-75.147087, 39.931236]                       None
#
#   properties.basements properties.beginning_point properties.book_and_page  \
# 0                    D  S W COR HOWARD                             0000000
# 1                    D  15D94 W HOWARD ST                          3209422
# 2                    D  30'51/2" W HOWARD                          0000000
# 3                    D  45'2" W HOWARD ST                          2448875
# 4                    C  59'6" W HOWARD ST                          3245897
#
#   properties.building_code properties.building_code_description  \
# 0                    P50                ROW W/GAR 3 STY MASONRY
# 1                    O50                      ROW 3 STY MASONRY
# 2                    O50                      ROW 3 STY MASONRY
# 3                    O50                      ROW 3 STY MASONRY
# 4                    O50                      ROW 3 STY MASONRY
#
#   properties.category_code  ... properties.unfinished properties.unit  \
# 0                        1  ...                  None            None
# 1                        1  ...                  None            None
# 2                        1  ...                  None            None
# 3                        1  ...                  None            None
# 4                        1  ...                  None            None
#
#   properties.utility properties.view_type properties.year_built  \
# 0               None                    I                  1920
# 1               None                    I                  1920
# 2               None                    I                  1920
# 3               None                    I                  1920
# 4               None                    I                  1920
#
#    properties.year_built_estimate  properties.zip_code  properties.zoning  \
# 0                               Y            191475425              RSA5
# 1                               Y            191475425              RSA5
# 2                               Y            191475425              RSA5
# 3                               Y            191475425              RSA5
# 4                               Y            191475425              RSA5
#
#   properties.objectid  geometry
# 0           832274881       NaN
# 1           832274882       NaN
# 2           832274883       NaN
# 3           832274884       NaN
# 4           832274885       NaN
#
# [5 rows x 79 columns]

# %%
properties_cols = [c.replace('.','_') for c in properties_df.columns]
properties_df.columns = properties_cols

# %%
with open('business_licenses.geojson','r') as f:
    licenses = json.load(f)

# %%
licenses_df = pd.json_normalize(licenses['features'])
licenses_df.head()
# Out:
#       type  geometry  properties.objectid  properties.addressobjectid  \
# 0  Feature       NaN                    1                    15698520
# 1  Feature       NaN                    2                    15499964
# 2  Feature       NaN                    3                    15793318
# 3  Feature       NaN                    4                    15419931
# 4  Feature       NaN                    5                    15531875
#
#     properties.address properties.unit_type properties.unit_num  \
# 0                 None                 None                None
# 1   4442 SILVERWOOD ST                 None                None
# 2     198 W ASHDALE ST                 None                None
# 3     2922 BOUDINOT ST                 None                None
# 4  8223 GERMANTOWN AVE                 None                None
#
#   properties.zip properties.censustract properties.parcel_id_num  ...  \
# 0           None                   None                     None  ...
# 1     19127-1329                    214                   385822  ...
# 2     19120-3428                   2.86                   181798  ...
# 3     19134-2905                 177.02                    62823  ...
# 4     19118-3401                   2.27                   489492  ...
#
#   properties.legalfirstname properties.legallastname  \
# 0                      None                     None
# 1                      None                     None
# 2                       ROM                      LAY
# 3        & CHRISTENSEN GARY    PIETRZYKOWSKI STEPHEN
# 4          RONALD & BEVERLY                     LOUX
#
#                        properties.legalname properties.legalentitytype  \
# 0                    509 VINE STREET TCE LP                    Company
# 1                              SOROKIN FRAN                    Company
# 2                                   LAY ROM                 Individual
# 3  PIETRZYKOWSKI STEPHEN & CHRISTENSEN GARY                 Individual
# 4                     LOUX RONALD & BEVERLY                 Individual
#
#     properties.business_name  \
# 0     509 VINE STREET TCE LP
# 1               SOROKIN FRAN
# 2                    LAY ROM
# 3  T/A HELP-U-BUY PROPERTIES
# 4               POPPY'S SEED
#
#                  properties.business_mailing_address properties.geocode_x  \
# 0         4328 Ridge Ave PHILADELPHIA, PA  19129 USA                  NaN
# 1           4361 MAIN ST PHILADELPHIA, PA  19127 USA         2.676135e+06
# 2       198 W ASHDALE ST PHILADELPHIA, PA  19120 USA         2.702920e+06
# 3  411 DOYLESTOWN RD. NO. 881 MONTGOMERYVILLE, PA...         2.704326e+06
# 4            144 COWPATH RD SOUDERTON, PA  18964 USA         2.681330e+06
#
#   properties.geocode_y geometry.type     geometry.coordinates
# 0                  NaN           NaN                      NaN
# 1        263258.845701         Point  [-75.222782, 40.028207]
# 2        263553.000000         Point  [-75.127149, 40.026871]
# 3        251449.698116         Point  [-75.123414, 39.993546]
# 4        280186.000000         Point  [-75.202497, 40.074245]
#
# [5 rows x 31 columns]

# %%
licenses_cols = [c.replace('.','_') for c in licenses_df.columns]
licenses_df.columns = licenses_cols

# %%
licenses_df.head()
# Out:
#       type  geometry  properties_objectid  properties_addressobjectid  \
# 0  Feature       NaN                    1                    15698520
# 1  Feature       NaN                    2                    15499964
# 2  Feature       NaN                    3                    15793318
# 3  Feature       NaN                    4                    15419931
# 4  Feature       NaN                    5                    15531875
#
#     properties_address properties_unit_type properties_unit_num  \
# 0                 None                 None                None
# 1   4442 SILVERWOOD ST                 None                None
# 2     198 W ASHDALE ST                 None                None
# 3     2922 BOUDINOT ST                 None                None
# 4  8223 GERMANTOWN AVE                 None                None
#
#   properties_zip properties_censustract properties_parcel_id_num  ...  \
# 0           None                   None                     None  ...
# 1     19127-1329                    214                   385822  ...
# 2     19120-3428                   2.86                   181798  ...
# 3     19134-2905                 177.02                    62823  ...
# 4     19118-3401                   2.27                   489492  ...
#
#   properties_legalfirstname properties_legallastname  \
# 0                      None                     None
# 1                      None                     None
# 2                       ROM                      LAY
# 3        & CHRISTENSEN GARY    PIETRZYKOWSKI STEPHEN
# 4          RONALD & BEVERLY                     LOUX
#
#                        properties_legalname properties_legalentitytype  \
# 0                    509 VINE STREET TCE LP                    Company
# 1                              SOROKIN FRAN                    Company
# 2                                   LAY ROM                 Individual
# 3  PIETRZYKOWSKI STEPHEN & CHRISTENSEN GARY                 Individual
# 4                     LOUX RONALD & BEVERLY                 Individual
#
#     properties_business_name  \
# 0     509 VINE STREET TCE LP
# 1               SOROKIN FRAN
# 2                    LAY ROM
# 3  T/A HELP-U-BUY PROPERTIES
# 4               POPPY'S SEED
#
#                  properties_business_mailing_address properties_geocode_x  \
# 0         4328 Ridge Ave PHILADELPHIA, PA  19129 USA                  NaN
# 1           4361 MAIN ST PHILADELPHIA, PA  19127 USA         2.676135e+06
# 2       198 W ASHDALE ST PHILADELPHIA, PA  19120 USA         2.702920e+06
# 3  411 DOYLESTOWN RD. NO. 881 MONTGOMERYVILLE, PA...         2.704326e+06
# 4            144 COWPATH RD SOUDERTON, PA  18964 USA         2.681330e+06
#
#   properties_geocode_y geometry_type     geometry_coordinates
# 0                  NaN           NaN                      NaN
# 1        263258.845701         Point  [-75.222782, 40.028207]
# 2        263553.000000         Point  [-75.127149, 40.026871]
# 3        251449.698116         Point  [-75.123414, 39.993546]
# 4        280186.000000         Point  [-75.202497, 40.074245]
#
# [5 rows x 31 columns]

# %%
def get_lat(x):
    
    if isinstance(x,list):
        if len(x) == 2: 
            return x[1]
        else:
            return np.nan
    else:
        return np.nan

def get_lon(x):
    
    if isinstance(x,list):
        if len(x) == 2: 
            return x[0]
        else:
            return np.nan
    else:
        return np.nan

# %%
licenses_df['latitude'] = licenses_df.geometry_coordinates.apply(lambda x: get_lat(x))
properties_df['latitude'] = properties_df.geometry_coordinates.apply(lambda x:  get_lat(x))

licenses_df['longitude'] = licenses_df.geometry_coordinates.apply(lambda x: get_lon(x))
properties_df['longitude'] = properties_df.geometry_coordinates.apply(lambda x: get_lon(x))

# %%
db_url = os.getenv('DB_URL')
eng = create_engine(db_url)

# %%
properties_drop_cols = [
    'geometry',
    'type',
    'geometry_type',
    'geometry_coordinates'
    
]
properties_df = properties_df.drop(columns=properties_drop_cols)

# %%
licenses_drop_cols = [
    'geometry',
    'type',
    'geometry_type',
    'geometry_coordinates'
    
]
licenses_df = licenses_df.drop(columns=licenses_drop_cols)

# %%
licenses_df.to_sql('licenses',
                   eng,if_exists='replace',
                   index=False,
                   chunksize=10000,
                   method='multi',
                   dtype=generate_schema(licenses_df)
                  )

# %%
properties_df.to_sql('properties',
                     eng,if_exists='replace',
                     index=False,chunksize=10000,
                     method='multi',
                     dtype=generate_schema(properties_df)
                    )
