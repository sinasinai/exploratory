# %% [markdown]
# ### Pulling in data

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %%
load_dotenv()
db = os.getenv('DB_URL')
engine = create_engine(db)

# %%
sql = '''

select
*
from west_philly_targets
where hav_dist(latitude,longitude, 39.9567,-75.23375) <= 1600 

'''

df = pd.read_sql(sql,engine)

# %%
df.head()
# Out:
#                 address    zip_code              coordinates market_value  \
# 0  141 COBBS CREEK PKWY       19139  [-75.246952, 39.960049]        69300
# 1  247 COBBS CREEK PKWY       19139  [-75.247354, 39.958344]       136800
# 2       115 DEARBORN ST  19139-0000  [-75.221855, 39.961644]        38400
# 3        12 DEARBORN ST  19139-0000  [-75.222452, 39.960069]        37400
# 4       120 DEARBORN ST  19139-0000  [-75.222097, 39.961756]        38400
#
#   opa_account_number                     opa_owner rental_license_number  \
# 0          031206500  COACH ELOISE, COACH HASTINGS                703482
# 1          031207800            ANDERSON CHRISTINA                727983
# 2          441082700                BUTLER HARRIET                226456
# 3          441085500     CHATHAM HOLDINGS SERVICES                736197
# 4          441088800                WALKER ARCELLA                367192
#
#   most_recent_license_issue_date license_expiration_date  \
# 0           2016-06-01T13:00:51Z    2017-05-31T00:00:00Z
# 1           2020-06-17T00:00:00Z    2021-02-07T00:00:00Z
# 2           2003-06-12T00:00:00Z    2004-02-29T00:00:00Z
# 3           2020-08-28T00:00:00Z    2021-04-20T00:00:00Z
# 4           2020-03-11T00:00:00Z    2021-02-28T00:00:00Z
#
#   license_inactive_date  ... properties_recording_date sale_price  \
# 0  2017-07-30T00:00:00Z  ...      2006-08-01T00:00:00Z         10
# 1                   nan  ...      2016-12-15T00:00:00Z     199000
# 2                   nan  ...      2004-07-08T00:00:00Z      45000
# 3                   nan  ...      2017-03-09T00:00:00Z      26500
# 4                   nan  ...      2006-05-10T00:00:00Z          1
#
#   taxable_building taxable_land total_area total_livable_area zoning  \
# 0            58910        10390    1578.99             1334.0  RM1
# 1            72306        19494     1280.0             1432.0  RM1
# 2                0            0      637.5              900.0  RSA5
# 3            31790         5610      667.5              900.0  RSA5
# 4            32640         5760      637.5              900.0  RSA5
#
#     target_type  longitude   latitude
# 0  smaller unit -75.246952  39.960049
# 1  smaller unit -75.247354  39.958344
# 2  smaller unit -75.221855  39.961644
# 3  smaller unit -75.222452  39.960069
# 4  smaller unit -75.222097  39.961756
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Clustering

# %%
from sklearn.cluster import KMeans

# %%
df = df.set_index('address')
cols = ['latitude','longitude']

# %%
kmeans = KMeans(n_clusters = 5,random_state=0).fit(df[cols])

# %%
clusters = kmeans.predict(X)
clusters = pd.DataFrame({'cluster':list(clusters)},index=df.index)

# %%
final = pd.concat([df,clusters],axis=1)

# %%
final.groupby('cluster').count()['coordinates']
# Out:
# cluster
# 0    2193
# 1    1896
# 2    2248
# 3    1987
# 4    1439
# Name: coordinates, dtype: int64

# %%
final.head()
# Out:
#                         zip_code              coordinates market_value  \
# address
# 141 COBBS CREEK PKWY       19139  [-75.246952, 39.960049]        69300
# 247 COBBS CREEK PKWY       19139  [-75.247354, 39.958344]       136800
# 115 DEARBORN ST       19139-0000  [-75.221855, 39.961644]        38400
# 12 DEARBORN ST        19139-0000  [-75.222452, 39.960069]        37400
# 120 DEARBORN ST       19139-0000  [-75.222097, 39.961756]        38400
#
#                      opa_account_number                     opa_owner  \
# address
# 141 COBBS CREEK PKWY          031206500  COACH ELOISE, COACH HASTINGS
# 247 COBBS CREEK PKWY          031207800            ANDERSON CHRISTINA
# 115 DEARBORN ST               441082700                BUTLER HARRIET
# 12 DEARBORN ST                441085500     CHATHAM HOLDINGS SERVICES
# 120 DEARBORN ST               441088800                WALKER ARCELLA
#
#                      rental_license_number most_recent_license_issue_date  \
# address
# 141 COBBS CREEK PKWY                703482           2016-06-01T13:00:51Z
# 247 COBBS CREEK PKWY                727983           2020-06-17T00:00:00Z
# 115 DEARBORN ST                     226456           2003-06-12T00:00:00Z
# 12 DEARBORN ST                      736197           2020-08-28T00:00:00Z
# 120 DEARBORN ST                     367192           2020-03-11T00:00:00Z
#
#                      license_expiration_date license_inactive_date  \
# address
# 141 COBBS CREEK PKWY    2017-05-31T00:00:00Z  2017-07-30T00:00:00Z
# 247 COBBS CREEK PKWY    2021-02-07T00:00:00Z                   nan
# 115 DEARBORN ST         2004-02-29T00:00:00Z                   nan
# 12 DEARBORN ST          2021-04-20T00:00:00Z                   nan
# 120 DEARBORN ST         2021-02-28T00:00:00Z                   nan
#
#                      license_status  ... sale_price taxable_building  \
# address                              ...
# 141 COBBS CREEK PKWY       Inactive  ...         10            58910
# 247 COBBS CREEK PKWY         Active  ...     199000            72306
# 115 DEARBORN ST            Inactive  ...      45000                0
# 12 DEARBORN ST               Active  ...      26500            31790
# 120 DEARBORN ST              Active  ...          1            32640
#
#                      taxable_land total_area total_livable_area zoning  \
# address
# 141 COBBS CREEK PKWY        10390    1578.99             1334.0  RM1
# 247 COBBS CREEK PKWY        19494     1280.0             1432.0  RM1
# 115 DEARBORN ST                 0      637.5              900.0  RSA5
# 12 DEARBORN ST               5610      667.5              900.0  RSA5
# 120 DEARBORN ST              5760      637.5              900.0  RSA5
#
#                        target_type  longitude   latitude cluster
# address
# 141 COBBS CREEK PKWY  smaller unit -75.246952  39.960049       0
# 247 COBBS CREEK PKWY  smaller unit -75.247354  39.958344       3
# 115 DEARBORN ST       smaller unit -75.221855  39.961644       2
# 12 DEARBORN ST        smaller unit -75.222452  39.960069       2
# 120 DEARBORN ST       smaller unit -75.222097  39.961756       2
#
# [5 rows x 36 columns]

# %%
final.loc[final.number_of_units.astype(float) > 10].shape
# Out:
# (12, 36)

# %%
final.to_sql('west_philly_clusters_20210211',engine,if_exists='replace',index=False,chunksize=10000,method='multi')

# %% [markdown]
# ### Mapping it all out

# %%
import keplergl
import geopandas as gp

# %%
points = final[['latitude','longitude','cluster']]
mapped = gp.GeoDataFrame(geometry=gp.points_from_xy(points.longitude, points.latitude),data=points)
mapped.head()
# Out:
#                        latitude  longitude  cluster  \
# address
# 141 COBBS CREEK PKWY  39.960049 -75.246952        0
# 247 COBBS CREEK PKWY  39.958344 -75.247354        3
# 115 DEARBORN ST       39.961644 -75.221855        2
# 12 DEARBORN ST        39.960069 -75.222452        2
# 120 DEARBORN ST       39.961756 -75.222097        2
#
#                                         geometry
# address
# 141 COBBS CREEK PKWY  POINT (-75.24695 39.96005)
# 247 COBBS CREEK PKWY  POINT (-75.24735 39.95834)
# 115 DEARBORN ST       POINT (-75.22186 39.96164)
# 12 DEARBORN ST        POINT (-75.22245 39.96007)
# 120 DEARBORN ST       POINT (-75.22210 39.96176)

# %%
m = keplergl.KeplerGl()

m.add_data(data=mapped.loc[mapped.cluster==0],name=f"Cluster 1")
m.add_data(data=mapped.loc[mapped.cluster==1],name=f"Cluster 2")
m.add_data(data=mapped.loc[mapped.cluster==2],name=f"Cluster 3")
m.add_data(data=mapped.loc[mapped.cluster==3],name=f"Cluster 4")
m.add_data(data=mapped.loc[mapped.cluster==4],name=f"Cluster 5")
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
m
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'lrwaer9', 'type': …

# %%
m.save_to_html(file_name="west_philly_turf_cluster_attempt.html")
# Out:
# Map saved to west_philly_turf_cluster_attempt.html!
